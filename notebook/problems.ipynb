# %% [markdown]
# # Probability distribution problems

# %% [markdown]
# ## Binomial distribution
#
# In probability theory and statistics, the binomial distribution is the discrete probability distribution that gives only two possible results in an experiment, for example, when you flip a coin it can by either head or tails.

# %%
from scipy.stats import binom

# Define all the probability functions related to this distribution

def dbinom(x, size, prob = 0.5):
    """
    Calculates the point estimate of the binomial distribution
    """
    result = binom.pmf(k = x, n = size, p = prob, loc = 0)

    return result

def pbinom(q, size, prob = 0.5):
    """
    Calculates the cumulative of the binomial distribution
    """
    result = binom.cdf(k = q, n = size, p = prob, loc = 0)

    return result

def qbinom(p, size, prob = 0.5):
    """
    Calculates the quantile function from the binomial distribution
    """
    result = binom.ppf(q = p, n = size, p = prob, loc = 0)

    return result

def rbinom(n, size, prob = 0.5):
    """
    Generates random variables from the binomial distribution
    """
    result = binom.rvs(n = size, p = prob, size = n)

    return result

# %%
# Binomial(10, 0.2) distribution where n = 10 is the number of trials and p = 0.2 is the probability of success in a single trial.
import numpy as np
np.random.seed(42)

print(f"Probability that a Binomial(10, 0.2) takes the value 2: {dbinom(2, size = 10, prob = 0.2)}")
print(f"Probability that a Binomial(10, 0.2) will take a value less than 2: {pbinom(2, size = 10, prob = 0.2)}")
print(f"Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? {qbinom(0.9, size = 10, prob = 0.2)}")
print(f"Generate 2000 random values from a Binomial(10, 0.2) distribution: {rbinom(2000, size = 10, prob = 0.2)}")
# Out:
# Probability that a Binomial(10, 0.2) takes the value 2: 0.30198988800000004
# Probability that a Binomial(10, 0.2) will take a value less than 2: 0.6777995263999999
# Which value of a Binomial(10, 0.2) has a cumulative probability of 0.9? 4.0
# Generate 2000 random values from a Binomial(10, 0.2) distribution: [1 4 3 ... 0 0 1]

# %%
import matplotlib.pyplot as plt

np.random.seed(42)

size = 10
prob = 0.2
data = rbinom(2000, size = 10, prob = 0.2)

pmf = dbinom(data, size = size, prob = prob)
cdf = pbinom(data, size = size, prob = prob)
ppf = qbinom(data, size = size, prob = prob)

fig, axis = plt.subplots(3, 1, figsize = (5, 7))

axis[0].stem(data, pmf, "r-")
axis[1].stem(data, cdf, "b-")
axis[2].stem(data, ppf, "g-")

# Adjust the layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Exercise 1
#
# Write the above functions but for both normal and uniform distributions.

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import numpy as np

# Parameters for the Normal distribution
mu = 0  # Mean
sigma = 1  # Standard deviation

# Generate random data from the Normal distribution
data = np.random.normal(mu, sigma, 1000)

# Calculate PDF for the random data
x = np.linspace(-3, 3, 100)
pdf = norm.pdf(x, loc=mu, scale=sigma)  # Calculate PDF directly

# Calculate CDF for the random data
cdf = norm.cdf(x, loc=mu, scale=sigma)  # Calculate CDF directly

# Calculate PPF for the random data
percentiles = norm.ppf(np.linspace(0, 1, 101), loc=mu, scale=sigma)  # Calculate PPF directly

# Calculate variables aleatorias (random variates)
random_variables_normal = normal_dist.rvs(size=1000)

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(5, 7))

# Plot PDF
axes[0].hist(data, bins=30, density=True, alpha=0.6, color='b', label='Data')
axes[0].plot(x, pdf, 'r', lw=2, label='PDF')
axes[0].set_title('Normal Distribution PDF')
axes[0].set_xlabel('Value')
axes[0].set_ylabel('Probability')
axes[0].legend()

# Plot CDF
axes[1].plot(x, cdf, color='g')
axes[1].set_title('Normal Distribution CDF')
axes[1].set_xlabel('Value')
axes[1].set_ylabel('Cumulative Probability')

# Plot PPF
axes[2].plot(np.linspace(0, 100, 101), percentiles, marker='o', linestyle='-', color='purple')
axes[2].set_title('Normal Distribution PPF (Quantiles)')
axes[2].set_xlabel('Percentile')
axes[2].set_ylabel('Value')

# Plot histogram for Random Variates (variables aleatorias)
plt.figure(figsize=(8, 4))
plt.hist(random_variables_normal, bins=30, density=True, alpha=0.6, color='b', label='Random Variates (Normal)')
plt.title('Histogram of Random Variates')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.legend()
plt.show()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Parameters for the Uniform distribution
low = 0
high = 1

# Generate random data from the Uniform distribution
data = np.random.uniform(low, high, 1000)

# Create a Uniform distribution object
uniform_dist = uniform(low, high - low)

# Probability density function (PDF) for the Uniform distribution
x = np.linspace(low - 0.1, high + 0.1, 100)
pdf = uniform_dist.pdf(x)

# Cumulative distribution function (CDF)
cdf = uniform_dist.cdf(x)

# Percent point function (PPF) - Quantiles
percentiles = uniform_dist.ppf(np.linspace(0, 1, 101))

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(5, 7))

# Plot PDF
axes[0].hist(data, bins=30, density=True, alpha=0.6, color='b')
axes[0].plot(x, pdf, 'r', lw=2)
axes[0].set_title('Uniform Distribution PDF')

# Plot CDF
axes[1].plot(x, cdf, color='g')
axes[1].set_title('Uniform Distribution CDF')

# Plot PPF
axes[2].plot(np.linspace(0, 100, 101), percentiles, marker='o', linestyle='-', color='purple')
axes[2].set_title('Uniform Distribution PPF (Quantiles)')


# Plot histogram for Random Variates (variables aleatorias)
plt.figure(figsize=(8, 4))
plt.hist(random_variables_uniform, bins=30, density=True, alpha=0.6, color='r', label='Random Variates (Uniform)')
plt.title('Histogram of Random Variates')
plt.xlabel('Value')
plt.ylabel('Probability')
plt.legend()
plt.show()

plt.tight_layout()
plt.show()
